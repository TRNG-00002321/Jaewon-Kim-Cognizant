# %%
""" 
HTTTP request is made up of:
-method:
    -put
    -get
    -patch
    -delete
    -post
    -head
    -options
    -connect
    -trace
-uri/url:
    -ex /users, /users/id, ect
-request header:
    -when user sends a request some info related to the client is sent to the server, so the server knows things like supported file type, browser,
     ip, ect
-request body:
    -this contains the data(in json format) being sent to the server

HTTP response is made up of:
    -status code:
        -1xx: informational
        -2xx: success
        -3xx: redirects
        -4xx: client errors
        -5xx: server errors
    -HTTP version
    -response header:
        -send meta data like content length, content type, ect.
    -response body:
        -this contains data(json) being sent from the server

FLASK: Is a light-weight(micro) web framework that comes with a built in server to make requests. It is based on certain tools such as:
    -wsgi(web server gateway interface)
    -werk zueg(look up): tool kit that impements the response and methods
    -jinaj (look up):

Flasks need a virtual enviroment
"""
# Out:
#   Cell In[4], line 41
#     pip install flask
#         ^
# SyntaxError: invalid syntax

# %%
pip install flask
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run flask_code.py
# Out:
#  * Serving Flask app 'flask_code'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Nov/2025 11:05:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2025 11:05:44] "GET /role/admin HTTP/1.1" 302 -
# 127.0.0.1 - - [10/Nov/2025 11:05:44] "GET /admin/admin HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2025 11:05:51] "GET /role/bob HTTP/1.1" 302 -
# 127.0.0.1 - - [10/Nov/2025 11:05:51] "GET /user/bob HTTP/1.1" 200 -

# %%
# %run form_handler.py
# Out:
#  * Serving Flask app 'form_handler'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Nov/2025 11:33:37] "POST /login HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2025 11:33:37] "GET /favicon.ico HTTP/1.1" 404 -
